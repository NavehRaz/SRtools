# %%
# %load_ext autoreload
# %autoreload 2
from SRtools import prior_gen as pg
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
gen = pg.PriorGen.prior_from_posterior_csv('test_prior.csv')

# %%
samp=gen.sample(100)

# %%
print(samp)
# Out:
# ['[6.252879878049444, 1.1793528748089597, 5.928494807705636, 7.806024018702079]'
#  '[6.215144616753631, 1.2433550553688555, 5.928494807705636, 7.236753989270358]'
#  '[6.089360412434255, 1.7553724998480207, 5.72773861570653, 6.525166452480706]'
#  '[6.303193559777195, 0.7953397914495857, 5.928494807705636, 6.809801467196566]'
#  '[6.089360412434255, 1.8193746804079165, 5.694279250373345, 6.809801467196566]'
#  '[6.278036718913319, 0.8593419720094815, 5.961954173038821, 7.023277728233461]'
#  '[6.039046730706504, 1.8833768609678123, 5.7110089330399365, 5.600102654654158]'
#  '[6.1899877758897555, 1.3713594164886467, 5.777927663706306, 6.311690191443811]'
#  '[6.265458298481382, 0.9233441525693773, 5.911765125039045, 4.888515117864506]'
#  '[6.152252514593942, 1.4353615970485425, 5.828116711706083, 6.0982139304069145]'
#  '[6.127095673730067, 1.6273681387282295, 5.811387029039491, 6.880960220875531]'
#  '[6.315771980209132, 0.28332234697042047, 6.0288729037051905, 6.16937268408588]'
# ...

# %%
gene=pg.PriorGenExtended.prior_from_posterior_csv_extended('test_prior.csv', [1,1], [0.7, 1.3], 2, True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 gene=pg.PriorGenExtended.prior_from_posterior_csv_extended('test_prior.csv', 1, [0.7, 1.3], 2, True)
#
# File ~/Dropbox/naveh/weizmann/uri alon/aging/code_3/SRtools/SRtools/prior_gen.py:69, in PriorGenExtended.prior_from_posterior_csv_extended(csv_path, seed, variations, ndims, draw_params_in_log_space)
#      67 values = df['unique_samples'].values
#      68 lnprobs = df['posterior'].values
# ---> 69 return PriorGenExtended(values, lnprobs, seed, variations, ndims, draw_params_in_log_space)
#
# File ~/Dropbox/naveh/weizmann/uri alon/aging/code_3/SRtools/SRtools/prior_gen.py:42, in PriorGenExtended.__init__(self, values, lnprobs, seed, variations, ndims, draw_params_in_log_space)
#      40 self.variations = variations
#      41 self.ndims = ndims
# ...
