# %%
pip install -e .
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///Volumes/alon/navehr/SRtools
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for SRtools (pyproject.toml) ... done
#   Created wheel for SRtools: filename=srtools-0.1-0.editable-py3-none-any.whl size=2644 sha256=5197628ac2972db4fd1ec66d95cd5570f9ec16531c86ceb38573835141c7a25d
#   Stored in directory: /private/var/folders/pr/hngn4yrn3v3gt3069stbsfqh0000gp/T/pip-ephem-wheel-cache-jwn7unza/wheels/84/d6/3b/aa6b346a920ff4391d447363a8df26fb56e5470e7425a46beb
# Successfully built SRtools
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# ...
